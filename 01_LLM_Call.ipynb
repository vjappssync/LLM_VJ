# %%
print("Welcome VJ - GREAT to SEE U Back in Action")
# Out:
# Welcome VJ - GREAT to SEE U Back in Action

# %%
import os
from dotenv import load_dotenv

load_dotenv(".env", override=True)
# load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("Open API Key Exists - TRUE")
    print(os.getenv("OPENAI_API_KEY"))
    print(os.getenv("GEMINI_API_KEY"))
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Open API Key Exists - TRUE
# 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
# AIzaSyB-nQcM4wE7Lzc-RsQiknG1vhWQv53S8Lc

# %%
from langchain_openai import ChatOpenAI

llmmodel = ChatOpenAI(model="gpt-5.4-nano", temperature=0.8)
llmmodel.invoke("what is newton's third law?").content
# Out:
# 'Newton’s **Third Law of Motion** says:\n\n**For every action, there is an equal and opposite reaction.**\n\nMore precisely: **If object A exerts a force on object B, object B exerts an equal-magnitude force in the opposite direction on object A**—and these forces act on different objects at the same time.\n\n**Example:** When you push on a wall, the wall pushes back on you with equal force.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
# import os
# os.environ["GEMINI_API_KEY"] = "AIzaSyArVgN7xureKf5NrGpC3Xh4rpjPzP6aA8c"

print(os.getenv("GEMINI_API_KEY"))
llmmodel= ChatGoogleGenerativeAI(model="gemini-2.5-flash", api_key=os.getenv("GEMINI_API_KEY"))
result = llmmodel.invoke("any latest AI technology from Google").content
print(result)

str_parser = StrOutputParser()
parsed_text = str_parser.parse(result)
print(parsed_text)
# Out:
# AIzaSyB-nQcM4wE7Lzc-RsQiknG1vhWQv53S8Lc
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[7], line 8
#       4 # os.environ["GEMINI_API_KEY"] = "AIzaSyArVgN7xureKf5NrGpC3Xh4rpjPzP6aA8c"
#       5
#       6 print(os.getenv("GEMINI_API_KEY"))
#       7 llmmodel= ChatGoogleGenerativeAI(model="gemini-2.5-flash", api_key=os.getenv("GEMINI_API_KEY"))
# ----> 8 result = llmmodel.invoke("any latest AI technology from Google").content
#       9 print(result)
#      10
#      11 str_parser = StrOutputParser()
#
# File g:\MY_FILES\TECH_CASE\LLM_CODE\VJ\LLM\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2559, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2556         msg = "Tools are already defined.code_execution tool can't be defined"
#    2557         raise ValueError(msg)
# ...

# %%
from langchain.chat_models import init_chat_model

llmmodel = init_chat_model(model="gpt-5.4-nano")
llmmodel.invoke("usage of 'init_chat_model' in 3 lines and not more than 30 words")

# llmmodel = init_chat_model(model="gemini-2.5-flash")
# llmmodel.invoke("usage of 'init_chat_model' in 3 lines and not more than 30 words").content
# Out:
# AIMessage(content='`init_chat_model` initializes a chat-capable LLM for conversational use.  \nPass model/provider settings (e.g., model name, API keys, parameters).  \nIt returns a callable/chat object for sending messages and receiving responses.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 24, 'total_tokens': 74, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DWPdMbMajcRSW3c1FmebaFfgXubaU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019da6a6-2d7b-7043-977e-bd81331f18f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 50, 'total_tokens': 74, 'input_token_detail
# ...
