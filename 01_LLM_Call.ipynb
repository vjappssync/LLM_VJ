# %%
print("Welcome VJ - GREAT to SEE U Back in Action")
# Out:
# Welcome VJ - GREAT to SEE U Back in Action

# %%
import os
from dotenv import load_dotenv

load_dotenv(".env", override=True)
# load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("Open API Key Exists - TRUE")
    print(os.getenv("OPENAI_API_KEY"))
    print(os.getenv("GEMINI_API_KEY"))
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Open API Key Exists - TRUE
# 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
# AIzaSyArVgN7xureKf5NrGpC3Xh4rpjPzP6aA8c

# %%
from langchain_openai import ChatOpenAI

llmmodel = ChatOpenAI(model="gpt-5.4-nano", temperature=0.8)
llmmodel.invoke("what is newton's third law?").content
# Out:
# 'Newton’s **third law of motion** states:\n\n**For every action, there is an equal and opposite reaction.**\n\nIn other words, when one object exerts a force on a second object, the second object exerts a force on the first object that is **equal in magnitude** and **opposite in direction**, acting on **different objects**.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
# import os
# os.environ["GEMINI_API_KEY"] = "AIzaSyArVgN7xureKf5NrGpC3Xh4rpjPzP6aA8c"

print(os.getenv("GEMINI_API_KEY"))
llmmodel= ChatGoogleGenerativeAI(model="gemini-2.5-flash", api_key=os.getenv("GEMINI_API_KEY"))
llmmodel.invoke("any latest AI technology from Google").content
# Out:
# AIzaSyArVgN7xureKf5NrGpC3Xh4rpjPzP6aA8c
# 'Google is constantly at the forefront of AI innovation, and "latest" can be a moving target given the rapid pace. However, here are the most significant and recent developments in Google\'s AI technology:\n\nThe overarching theme for Google\'s latest AI is **Gemini**, their family of multimodal large language models (LLMs), and its integration across their entire ecosystem.\n\n1.  **Gemini (The Flagship LLM):**\n    *   **Gemini 1.5 Pro:** This is the latest iteration of their most powerful model, known for its massive **1-million-token context window**. This allows it to process incredibly long documents, entire codebases, hours of video, or many audio files at once, enabling sophisticated summarization, analysis, and understanding across various modalities.\n    *   **Gemini Advanced:** This is the premium version of Gemini, powered by Gemini 1.5 Pro, offering more advanced reasoning, coding, and creative capabilities. It replaced the "Bard Advanced" offering.\n    *   **Gemini Nano:** A smaller, highly efficient version designed to run directly on devices (like Pixel phones) for on-device AI features without needing a cloud connection.\n    *   **Multimodality:** Gemini is inherently multimodal, meaning it can understand and reason across text, images, audio, and video inputs simultaneously, and generate outputs in various formats.\n\n2.  **Integration Across Google Products (Gemini Everywhere):**\n    *   **Google Search (Search Generative Experience - SGE):** AI is deeply integrated into Search, providing generative AI overviews, conversational search experiences, and tools to refine queries or explore topics more deeply.\n    *   **Google Workspace (Gemini for Workspace / Duet AI):** AI assistants are embedded in Gmail, Docs, Sheets, and Slides to help with writing, summarizing, generating content (e.g., creating images in Slides from text prompts), organizing data, and more.\n    *   **Google Pixel Devices:** Pixel phones leverage Gemini Nano for features like Magic Editor (advanced photo editing), Summarize in Recorder, Call Screen improvements, and Smart Reply suggestions.\n    *   **Android OS:** AI features are being baked directly into Android, leveraging Gemini\'s capabilities for a more personalized and helpful smartphone experience.\n    *   **YouTube:** AI is used for content creation, summarization of videos, enhanced search, and discovery.\n\n3.  **Generative AI for Creation:**\n    *   **Imagen 3:** Google\'s latest text-to-image generation model, known for its high quality, photorealism, and ability to understand nuanced prompts.\n    *   **MusicFX / MusicLM:** Tools for generating music from text descriptions.\n    *   **Video Generation:** While not as publicly available as text and image generation, Google is actively researching and developing advanced video generation models.\n\n4.  **DeepMind\'s Scientific Breakthroughs:**\n    *   **AlphaFold 3:** The latest version of their groundbreaking AI system for predicting protein structures, now capable of predicting the structure and interactions of *all* life\'s molecules (proteins, DNA, RNA, small molecules). This has massive implications for drug discovery and biological research.\n    *   **Robotics and Embodied AI:** DeepMind continues to push boundaries in AI for robotics, enabling more versatile and adaptive robots.\n\n5.  **AI Infrastructure:**\n    *   **TPUs (Tensor Processing Units):** Google continues to develop its custom-designed chips optimized for AI workloads, providing the computational backbone for training and running their massive AI models efficiently.\n\n**Key Trends and Focus Areas:**\n*   **Multimodality:** The ability for AI to understand and generate across different types of data (text, images, audio, video).\n*   **Long Context Windows:** Processing and reasoning over vast amounts of information.\n*   **On-device AI:** Bringing powerful AI capabilities directly to user devices for privacy, speed, and offline functionality.\n*   ...

# %%
from langchain.chat_models import init_chat_model

llmmodel = init_chat_model(model="gpt-5.4-nano")
llmmodel.invoke("usage of 'init_chat_model' in 3 lines and not more than 30 words")

# llmmodel = init_chat_model(model="gemini-2.5-flash")
# llmmodel.invoke("usage of 'init_chat_model' in 3 lines and not more than 30 words").content
# Out:
# AIMessage(content='`init_chat_model` initializes a chat-capable LLM for conversational use.  \nPass model/provider settings (e.g., model name, API keys, parameters).  \nIt returns a callable/chat object for sending messages and receiving responses.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 24, 'total_tokens': 74, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DWPdMbMajcRSW3c1FmebaFfgXubaU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019da6a6-2d7b-7043-977e-bd81331f18f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 50, 'total_tokens': 74, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
