# %%
print("Welcome VJ - GREAT to SEE U Back in Action")
# Out:
# Welcome VJ - GREAT to SEE U Back in Action

# %%
import os
from dotenv import load_dotenv

load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("Open API Key Exists")
    print(os.getenv("OPENAI_API_KEY"))
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Open API Key Exists
# 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

# %%
from langchain_openai import ChatOpenAI

llmmodel = ChatOpenAI(model="gpt-5-mini", temperature=0.8)
llmmodel.invoke("what is newton's third law?").content
# Out:
# "Newton's third law (law of action and reaction):\n\n- For every force exerted by object A on object B, there is an equal in magnitude and opposite in direction force exerted by B on A.\n- Symbolically: F_AB = −F_BA.\n\nKey points:\n- The two forces act on different objects, not on the same object, so they do not cancel each other.\n- The law explains why momentum is conserved for an isolated system: internal forces come in equal-and-opposite pairs.\n- It applies in classical (Newtonian) mechanics; in some electromagnetic or relativistic contexts you must also account for fields to see the momentum balance.\n\nSimple examples:\n- Pushing on a wall: you exert a force on the wall; the wall exerts an equal and opposite force on you.\n- Rocket thrust: hot gas is pushed backward; the gas pushes the rocket forward with equal and opposite force.\n- Walking: your foot pushes backward on the ground; the ground pushes your foot forward, propelling you."
